# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranjal-Waghmare/PROJECTS/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import the libraries as shown below

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50
from keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# re-size all the images to this
IMAGE_SIZE = [224, 224]

train_path = '/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Train'
valid_path = '/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Test'

# %%
# Import the Vgg 16 library as shown below and add preprocessing layer to the front of VGG
# Here we will be using imagenet weights

resnet = ResNet50(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# ...
# 94773248/94765736 [==============================] - 1s 0us/step

# %%
resnet.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %%
# don't train existing weights
for layer in resnet.layers:
    layer.trainable = False

# %%
# useful for getting number of output classes
folders = glob('/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Train/*')

# %%
folders
# Out:
# ['/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Train/sunflower',
#  '/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Train/dandelion',
#  '/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Train/rose',
#  '/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Train/daisy',
#  '/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Train/tulip']

# %%
folders1 = glob('/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Test/*')

# %%
folders1
# Out:
# ['/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Test/sunflower',
#  '/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Test/tulip',
#  '/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Test/rose',
#  '/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Test/daisy',
#  '/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Test/dandelion']

# %%
import pandas as pd
import numpy as np

# %%
x= Flatten()(resnet.output)

# %%
prediction= Dense(len(folders),activation='softmax')(x)

model=Model(inputs=resnet.input,outputs=prediction)

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %%
model.compile(
              loss='categorical_crossentropy',
            optimizer='adam',
             metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen= ImageDataGenerator(rescale=1./255,
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True)

test_datagen= ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory('/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Train',
                                                  target_size=(224,224),
                                                  batch_size=32,
                                                  class_mode='categorical')
# Out:
# Found 3058 images belonging to 5 classes.

# %%
test_set = test_datagen.flow_from_directory('/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Test',
                                                  target_size=(224,224),
                                                  batch_size=32,
                                                  class_mode='categorical')
# Out:
# Found 1265 images belonging to 5 classes.

# %%
r= model.fit_generator(
                       training_set,
                       validation_data=test_set,
                       epochs=50,
                       steps_per_epoch=len(training_set),
                       validation_steps= len(test_set))
# Out:
# WARNING:tensorflow:From <ipython-input-19-d1b0828be79d>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 96/96 [==============================] - 1591s 17s/step - loss: 3.2806 - accuracy: 0.3100 - val_loss: 1.6000 - val_accuracy: 0.4292
# Epoch 2/50
# 96/96 [==============================] - 632s 7s/step - loss: 1.6494 - accuracy: 0.3983 - val_loss: 1.7964 - val_accuracy: 0.4126
# Epoch 3/50
# 96/96 [==============================] - 633s 7s/step - loss: 1.6427 - accuracy: 0.4264 - val_loss: 1.7423 - val_accuracy: 0.3692
# Epoch 4/50
# 96/96 [==============================] - 633s 7s/step - loss: 1.4282 - accuracy: 0.4663 - val_loss: 1.3387 - val_accuracy: 0.4996
# Epoch 5/50
# 96/96 [==============================] - 633s 7s/step - loss: 1.4877 - accuracy: 0.4948 - val_loss: 1.3196 - val_accuracy: 0.5194
# ...

# %%
y_pred= model.predict(test_set)

# %%
y_pred
# Out:
# array([[9.8585749e-01, 3.1705466e-03, 1.5229607e-03, 7.0855971e-03,
#         2.3634282e-03],
#        [9.8114610e-03, 3.4488846e-02, 1.9277710e-03, 9.3374538e-01,
#         2.0026587e-02],
#        [9.8570943e-01, 7.0226367e-04, 1.7381524e-03, 3.9467990e-04,
#         1.1455516e-02],
#        ...,
#        [1.9367348e-01, 8.4138229e-02, 1.5603660e-02, 1.5900756e-01,
#         5.4757702e-01],
#        [9.0075485e-02, 7.6870456e-02, 4.1736647e-01, 3.7755755e-01,
#         3.8130067e-02],
#        [6.9672833e-03, 6.6037995e-01, 6.0123634e-03, 3.7137568e-02,
#         2.8950298e-01]], dtype=float32)

# %%
from tensorflow.keras.models import  load_model
from tensorflow.keras.preprocessing import image

# %%
model.save('my_model.h5')

# %%
model= load_model('my_model.h5')

# %%
img=image.load_img('/content/drive/My Drive/Colab Notebooks/Flower_Datasets/Test/daisy/14333681205_a07c9f1752_m.jpg',target_size=(224,224))

# %%
x=image.img_to_array(img)
x
# Out:
# array([[[ 57.,  94.,  40.],
#         [ 59.,  87.,  39.],
#         [ 36.,  50.,  14.],
#         ...,
#         [  6.,  18.,   0.],
#         [  7.,  19.,   0.],
#         [  8.,  20.,   0.]],
#
#        [[ 56.,  83.,  38.],
#         [ 29.,  50.,  11.],
#         [ 37.,  48.,  16.],
#         ...,
#         [  7.,  18.,   1.],
#         [  7.,  18.,   1.],
#         [  8.,  19.,   2.]],
#
#        [[ 49.,  66.,  30.],
#         [ 32.,  45.,  15.],
#         [ 27.,  37.,  10.],
#         ...,
#         [  3.,  14.,   0.],
#         [  4.,  15.,   0.],
#         [  4.,  15.,   0.]],
#
#        ...,
#
#        [[  3.,  10.,   2.],
#         [  2.,   9.,   1.],
#         [  2.,   9.,   1.],
#         ...,
#         [203., 134.,   0.],
#         [213., 137.,   0.],
#         [214., 131.,   0.]],
#
#        [[  3.,  10.,   2.],
#         [  1.,   8.,   0.],
#         [  1.,   8.,   0.],
#         ...,
#         [172.,  96.,   2.],
#         [201., 119.,  11.],
# ...

# %%
x.shape
# Out:
# (224, 224, 3)

# %%
x=x/255

# %%
x=np.expand_dims(x,axis=0)
img_data=preprocess_input(x)
img_data.shape
# Out:
# (1, 224, 224, 3)

# %%
model.predict(img_data)
# Out:
# array([[1.0000000e+00, 2.4846197e-27, 3.6135848e-19, 9.7148906e-13,
#         6.8101053e-11]], dtype=float32)

# %%
a=np.argmax(model.predict(img_data), axis=1)

# %%
a
# Out:
# array([0])
